# %% [markdown]
# Variables

# %% [markdown]
# **str** "login" URLs, selectors, messages
#
# **int**  404 Status codes, counts
#
# **float** 0.95 Timeouts, thresholds
#
# **bool** TrueAssertions, pass/fail flags

# %%
name = "Dona" # double quote is used here
name2 = 'Maria' #single quote also fine
print(f"Hello, {name} {name2} !")  # Hello, Dona Maria!
# Out:
# Hello, Dona Maria !

# %%
page = "login"
wait = 30 
wait2 = 0.3 
is_logged_in = False 
print(f"{page} Page. Wait for {wait+wait2}. User in? {is_logged_in}")
# Out:
# login Page. Wait for 30.3. User in? False
