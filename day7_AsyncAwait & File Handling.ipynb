# %% [markdown]
# Async/Await & File Handling

# %% [markdown]
# async def: defines an async function
#
# await: waits for this to finish before next line
#
# asyncio.run(): runs the async function

# %%
#async
import asyncio

async def run_test(page):
    print(f"🔄 Testing {page}...")
    await asyncio.sleep(1)        # simulates browser waiting
    print(f"✅ {page} done!")

# asyncio.run(run_test("login")) # for normal .py file

# ✅ Jupyter fix — use await directly instead of asyncio.run()
await run_test_suite()
# Out:
# 🔄 Running login test...
# ✅ login test done!
# 🔄 Running signup test...
# ✅ signup test done!
# 🔄 Running dashboard test...
# ✅ dashboard test done!
# 📄 All results saved to test_results.txt!

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# File handling
# Writing to a file
with open("results.txt", "w") as f:
    f.write("Login Test: Passed\n")
    f.write("Signup Test: Failed\n")

# Reading from a file
with open("results.txt", "r") as f:
    content = f.read()
    print(content)
# Out:
# Login Test: Passed
# Signup Test: Failed

# %%
#both combined

import asyncio

async def run_test_suite():
    pages = ["login", "signup", "dashboard"]
    results = []

    for page in pages:
        print(f"🔄 Running {page} test...")
        await asyncio.sleep(0.5)        # simulates browser wait
        results.append(f"{page}: passed")
        print(f"✅ {page} test done!")

    # Save to file
    with open("test_results.txt", "w") as f:
        for result in results:
            f.write(result + "\n")

    print("📄 All results saved to test_results.txt!")

# asyncio.run(run_test("login")) # for normal .py file

# ✅ Jupyter fix — use await directly instead of asyncio.run()
await run_test_suite()
# Out:
# 🔄 Running login test...
# ✅ login test done!
# 🔄 Running signup test...
# ✅ signup test done!
# 🔄 Running dashboard test...
# ✅ dashboard test done!
# 📄 All results saved to test_results.txt!

# %%
# Is called run_test_suite
# Has a list of 3 pages — "login", "signup", "home"
# Loops through pages with await asyncio.sleep(0.5)
# Prints "✅ {page} test done!" for each page
# Saves all results to "suite_results.txt"
# Calls it with asyncio.run()
